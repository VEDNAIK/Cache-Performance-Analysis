# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

associativity = [2, 4, 8]
total_cycles_128 = [12129641, 11928753, 12114705]
total_cycles_150 = [15008504, 14978804, 14786272]

plt.figure(figsize=(10, 5))
plt.plot(associativity, total_cycles_128, marker='o', label='Matrix Size 128x128')
plt.plot(associativity, total_cycles_150, marker='o', label='Matrix Size 150x150')
plt.xlabel('Cache Associativity')
plt.ylabel('Total Cycles')
plt.title('Total Cycles vs. Cache Associativity')
plt.legend()
plt.grid(True)
plt.show()

# %%
cache1_misses_128 = [64060, 60679, 63561]
cache1_misses_150 = [66034, 66034, 55334]

plt.figure(figsize=(10, 5))
plt.plot(associativity, cache1_misses_128, marker='o', label='Matrix Size 128x128')
plt.plot(associativity, cache1_misses_150, marker='o', label='Matrix Size 150x150')
plt.xlabel('Cache Associativity')
plt.ylabel('Cache 1 Misses')
plt.title('Cache 1 Misses vs. Cache Associativity')
plt.legend()
plt.grid(True)
plt.show()

# %%
amat_cache1_128 = [40.24, 37.56, 39.05]
amat_cache1_150 = [46.74, 46.74, 43.61]

plt.figure(figsize=(10, 5))
plt.plot(associativity, amat_cache1_128, marker='o', label='Matrix Size 128x128')
plt.plot(associativity, amat_cache1_150, marker='o', label='Matrix Size 150x150')
plt.xlabel('Cache Associativity')
plt.ylabel('AMAT (Cache 1)')
plt.title('AMAT (Cache 1) vs. Cache Associativity')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

block_sizes = [16, 32, 64]
total_cycles_128 = [12129641, 11459193, 10740613]
total_cycles_150 = [14909288, 14496496, 13875183]  # Provided total cycles for matrix size 150

plt.figure(figsize=(12, 6))
plt.plot(block_sizes, total_cycles_128, marker='o', label='Matrix Size 128')
plt.plot(block_sizes, total_cycles_150, marker='o', label='Matrix Size 150')
plt.xlabel('Block Size')
plt.ylabel('Total Cycles Taken')
plt.title('Total Cycles Taken vs Block Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

cache_levels = ['cache_1', 'cache_2', 'cache_3']
misses_128 = [
    [64060, 32630, 19353],  
    [14140, 13825, 10313],
    [5355, 5446, 5425]      
]
misses_150 = [
    [63081, 38645, 32630],  
    [17959, 17274, 6992],   
    [7055, 6992, 5425]      
]

x = np.arange(len(block_sizes))

fig, ax = plt.subplots(figsize=(12, 8))

for i, cache_level in enumerate(cache_levels):
    ax.plot(block_sizes, [misses_128[i], misses_150[i]], marker='o', label=f'{cache_level} Misses')

ax.set_xlabel('Block Size')
ax.set_ylabel('Number of Misses')
ax.set_title('Cache Misses vs Block Size')
ax.legend()
ax.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 20
#      17 fig, ax = plt.subplots(figsize=(12, 8))
#      19 for i, cache_level in enumerate(cache_levels):
# ---> 20     ax.plot(block_sizes, [misses_128[i], misses_150[i]], marker='o', label=f'{cache_level} Misses')
#      22 ax.set_xlabel('Block Size')
#      23 ax.set_ylabel('Number of Misses')
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# ...

# %%
amats_128 = [40.239, 39.860, 38.074]
amats_150 = [46.130, 44.679, 43.000]  # Provided AMATs for matrix size 150

plt.figure(figsize=(12, 6))
plt.plot(block_sizes, amats_128, marker='o', label='Matrix Size 128')
plt.plot(block_sizes, amats_150, marker='o', label='Matrix Size 150')
plt.xlabel('Block Size')
plt.ylabel('AMAT')
plt.title('AMAT vs Block Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
cache_levels = ['1 Cache', '2 Cache', '3 Cache']
total_cycles = [76937677, 20140349, 12129641]
amat_cache_1 = [267.13, 63.71, 40.24]
amat_cache_2 = [None, 267.82, 147.42]  # No Cache 2 in 1-cache system
amat_cache_3 = [None, None, 516.05]     # No Cache 3 in 1 or 2-cache systems

hits_cache_1 = [176626, 184319, 176617]
misses_cache_1 = [64051, 56358, 64060]
hits_cache_2 = [None, 37477, 41382]
misses_cache_2 = [None, 12614, 14140]
hits_cache_3 = [None, None, 7516]
misses_cache_3 = [None, None, 5355]

# Replace None with 0 for plotting
amat_cache_2 = [0 if x is None else x for x in amat_cache_2]
amat_cache_3 = [0 if x is None else x for x in amat_cache_3]
hits_cache_2 = [0 if x is None else x for x in hits_cache_2]
misses_cache_2 = [0 if x is None else x for x in misses_cache_2]
hits_cache_3 = [0 if x is None else x for x in hits_cache_3]
misses_cache_3 = [0 if x is None else x for x in misses_cache_3]

# Plot 1: Total Cycles
plt.figure(figsize=(10, 6))
plt.bar(cache_levels, total_cycles, color='skyblue')
plt.xlabel('Cache Configuration')
plt.ylabel('Total Cycles')
plt.title('Total Cycles Taken by Cache Configurations')
plt.show()

# Plot 2: AMAT for Different Cache Levels
plt.figure(figsize=(10, 6))
x = np.arange(len(cache_levels))
width = 0.2

plt.bar(x - width, amat_cache_1, width, label='Cache 1', color='steelblue')
plt.bar(x, amat_cache_2, width, label='Cache 2', color='lightgreen')
plt.bar(x + width, amat_cache_3, width, label='Cache 3', color='salmon')

plt.xlabel('Cache Configuration')
plt.ylabel('AMAT (ns)')
plt.title('Average Memory Access Time (AMAT)')
plt.xticks(x, cache_levels)
plt.legend()
plt.show()

# Plot 3: Hits and Misses for Cache 1
plt.figure(figsize=(10, 6))
width = 0.3
x = np.arange(len(cache_levels))

plt.bar(x - width/2, hits_cache_1, width, label='Hits (Cache 1)', color='green')
plt.bar(x + width/2, misses_cache_1, width, label='Misses (Cache 1)', color='red')

plt.xlabel('Cache Configuration')
plt.ylabel('Count')
plt.title('Cache 1 Hits and Misses')
plt.xticks(x, cache_levels)
plt.legend()
plt.show()

# Plot 4: Hits and Misses for Cache 2 and 3 (for 2 and 3 cache configurations)
plt.figure(figsize=(12, 8))

# Cache 2 Hits/Misses
plt.subplot(2, 1, 1)
plt.bar(['2 Cache', '3 Cache'], [hits_cache_2[1], hits_cache_2[2]], width, label='Hits (Cache 2)', color='green')
plt.bar(['2 Cache', '3 Cache'], [misses_cache_2[1], misses_cache_2[2]], width, label='Misses (Cache 2)', color='red')
plt.title('Cache 2 Hits and Misses')
plt.ylabel('Count')
plt.legend()

# Cache 3 Hits/Misses
plt.subplot(2, 1, 2)
plt.bar(['3 Cache'], [hits_cache_3[2]], width, label='Hits (Cache 3)', color='green')
plt.bar(['3 Cache'], [misses_cache_3[2]], width, label='Misses (Cache 3)', color='red')
plt.title('Cache 3 Hits and Misses')
plt.ylabel('Count')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
caches = ['cache_1', 'cache_2', 'cache_3']
accesses = [184040, 38102, 5199]
hits = [139161, 31774, 2445]
misses = [44879, 6328, 2754]
AMATs = [244.8546, 182.0805, 629.7173]
total_cycles = [55843040, 9511312, 5187932]

# Plot AMATs
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.bar(caches, AMATs, color=['blue', 'orange', 'green'])
plt.xlabel('Cache Type')
plt.ylabel('Average Memory Access Time (AMAT)')
plt.title('AMAT for Different Cache Configurations')

# Plot Hit/Miss Statistics
width = 0.2  # Width of the bars
x = np.arange(len(caches))

plt.subplot(1, 2, 2)
bar1 = plt.bar(x - width, hits, width, label='Hits', color='blue')
bar2 = plt.bar(x, misses, width, label='Misses', color='red')
bar3 = plt.bar(x + width, accesses, width, label='Accesses', color='gray')

plt.xlabel('Cache Type')
plt.ylabel('Counts')
plt.title('Cache Hit/Miss/Access Counts')
plt.xticks(x, caches)
plt.legend()

plt.tight_layout()
plt.show()

# %%
cache_levels = ['1 Cache', '2 Cache', '3 Cache']
total_cycles = [55843040, 9511312, 5187932]

amat_cache_1 = [244.85, 45.41, 26.33]
amat_cache_2 = [None, 182.08, 111.19]
amat_cache_3 = [None, None, 629.72]

hits_cache_1 = [139161, 139150, 142111]
misses_cache_1 = [44879, 44890, 41929]

hits_cache_2 = [None, 31774, 30490]
misses_cache_2 = [None, 6328, 5430]

hits_cache_3 = [None, None, 2445]
misses_cache_3 = [None, None, 2754]

# %%
amat_cache_2 = [0 if x is None else x for x in amat_cache_2]
amat_cache_3 = [0 if x is None else x for x in amat_cache_3]
hits_cache_2 = [0 if x is None else x for x in hits_cache_2]
misses_cache_2 = [0 if x is None else x for x in misses_cache_2]
hits_cache_3 = [0 if x is None else x for x in hits_cache_3]
misses_cache_3 = [0 if x is None else x for x in misses_cache_3]

# Plot 1: Total Cycles
plt.figure(figsize=(10, 6))
plt.bar(cache_levels, total_cycles, color='skyblue')
plt.xlabel('Cache Configuration')
plt.ylabel('Total Cycles')
plt.title('Total Cycles Taken by Cache Configurations')
plt.show()

# Plot 2: AMAT for Different Cache Levels
plt.figure(figsize=(10, 6))
x = np.arange(len(cache_levels))
width = 0.2

plt.bar(x - width, amat_cache_1, width, label='Cache 1', color='steelblue')
plt.bar(x, amat_cache_2, width, label='Cache 2', color='lightgreen')
plt.bar(x + width, amat_cache_3, width, label='Cache 3', color='salmon')

plt.xlabel('Cache Configuration')
plt.ylabel('AMAT (ns)')
plt.title('Average Memory Access Time (AMAT)')
plt.xticks(x, cache_levels)
plt.legend()
plt.show()

# Plot 3: Hits and Misses for Cache 1
plt.figure(figsize=(10, 6))
width = 0.3
x = np.arange(len(cache_levels))

plt.bar(x - width/2, hits_cache_1, width, label='Hits (Cache 1)', color='green')
plt.bar(x + width/2, misses_cache_1, width, label='Misses (Cache 1)', color='red')

plt.xlabel('Cache Configuration')
plt.ylabel('Count')
plt.title('Cache 1 Hits and Misses')
plt.xticks(x, cache_levels)
plt.legend()
plt.show()

# Plot 4: Hits and Misses for Cache 2 and 3 (for 2 and 3 cache configurations)
plt.figure(figsize=(12, 8))

# Cache 2 Hits/Misses
plt.subplot(2, 1, 1)
plt.bar(['2 Cache', '3 Cache'], [hits_cache_2[1], hits_cache_2[2]], width, label='Hits (Cache 2)', color='green')
plt.bar(['2 Cache', '3 Cache'], [misses_cache_2[1], misses_cache_2[2]], width, label='Misses (Cache 2)', color='red')
plt.title('Cache 2 Hits and Misses')
plt.ylabel('Count')
plt.legend()

# Cache 3 Hits/Misses
plt.subplot(2, 1, 2)
plt.bar(['3 Cache'], [hits_cache_3[2]], width, label='Hits (Cache 3)', color='green')
plt.bar(['3 Cache'], [misses_cache_3[2]], width, label='Misses (Cache 3)', color='red')
plt.title('Cache 3 Hits and Misses')
plt.ylabel('Count')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Scatter Operation

# %%
import matplotlib.pyplot as plt
import numpy as np

block_sizes = [16, 32, 64]

# Data for Total Cycles Taken
total_cycles_128 = [12129641, 11459193, 10740613]
total_cycles_150 = [14909288, 14496496, 13875183]  

# Data for Cache Misses
misses_128 = {
    'cache_1': [64060, 32630, 19353],
    'cache_2': [14140, 13825, 10313],
    'cache_3': [5355, 5446, 5425]
}
misses_150 = {
    'cache_1': [63081, 38645, 32630],
    'cache_2': [17959, 17274, 6992],
    'cache_3': [7055, 6992, 5425]
}

# Data for AMAT
amats_128 = {
    'cache_1': [40.239, 39.860, 38.074],
    'cache_2': [147.425, 286.633, 461.059],
    'cache_3': [516.052, 535.471, 697.862]
}
amats_150 = {
    'cache_1': [46.130, 44.680, 43.000], 
    'cache_2': [187.695, 296.531, 552.293],
    'cache_3': [535.037, 552.293, 697.862]  

fig, ax1 = plt.subplots(figsize=(14, 8))

color = 'tab:blue'
ax1.set_xlabel('Block Size')
ax1.set_ylabel('Total Cycles Taken', color=color)
ax1.plot(block_sizes, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(block_sizes, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses', color=color)
for cache_level in misses_128:
    ax2.plot(block_sizes, misses_128[cache_level], marker='x', label=f'{cache_level} Misses (128)', linestyle='dotted')
for cache_level in misses_150:
    ax2.plot(block_sizes, misses_150[cache_level], marker='x', label=f'{cache_level} Misses (150)', linestyle='dashdot')
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 80))
ax3.set_ylabel('AMAT', color=color)
for cache_level in amats_128:
    ax3.plot(block_sizes, amats_128[cache_level], marker='s', label=f'{cache_level} AMAT (128)', linestyle='solid')
for cache_level in amats_150:
    ax3.plot(block_sizes, amats_150[cache_level], marker='s', linestyle='dashed', label=f'{cache_level} AMAT (150)')
ax3.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.title('Performance Metrics vs Block Size')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

block_sizes = [16, 32, 64]

# Data for Total Cycles Taken
total_cycles_128 = [12129641, 11459193, 10740613]
total_cycles_150 = [14909288, 14496496, 13875183]  # Provided total cycles for matrix size 150

# Data for Cache Misses for cache_1
misses_128_cache_1 = [64060, 32630, 19353]
misses_150_cache_1 = [63081, 38645, 32630]

# Data for AMAT for cache_1
amats_128_cache_1 = [40.239, 39.860, 38.074]
amats_150_cache_1 = [46.130, 44.680, 43.000]  # Provided AMATs for matrix size 150

fig, ax1 = plt.subplots(figsize=(14, 8))

color = 'tab:blue'
ax1.set_xlabel('Block Size')
ax1.set_ylabel('Total Cycles Taken', color=color)
ax1.plot(block_sizes, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(block_sizes, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses (cache_1)', color=color)
ax2.plot(block_sizes, misses_128_cache_1, marker='x', label='Cache Misses (128)', linestyle='dotted', color=color)
ax2.plot(block_sizes, misses_150_cache_1, marker='x', label='Cache Misses (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('AMAT (cache_1)', color=color)
ax3.plot(block_sizes, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(block_sizes, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.title('Performance Metrics vs Block Size')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

block_sizes = [16, 32, 64]

# Data for Total Cycles Taken
total_cycles_128 = [12129641, 11459193, 10740613]
total_cycles_150 = [14909288, 14496496, 13875183]  # Provided total cycles for matrix size 150

# Data for Cache Misses for cache_1
misses_128_cache_1 = [64060, 32630, 19353]
misses_150_cache_1 = [63081, 38645, 32630]

# Assume total memory accesses
total_memory_accesses = 10000000

# Convert cache misses to miss rates
miss_rate_128_cache_1 = [miss / total_memory_accesses for miss in misses_128_cache_1]
miss_rate_150_cache_1 = [miss / total_memory_accesses for miss in misses_150_cache_1]

# Data for AMAT for cache_1
amats_128_cache_1 = [40.239, 39.860, 38.074]
amats_150_cache_1 = [46.130, 44.680, 43.000]  # Provided AMATs for matrix size 150

fig, ax1 = plt.subplots(figsize=(14, 8))

color = 'tab:blue'
ax1.set_xlabel('Block Size', fontsize=20)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(block_sizes, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(block_sizes, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Miss Rate', color=color, fontsize=20)
ax2.plot(block_sizes, miss_rate_128_cache_1, marker='x', label='Cache Miss Rate (128)', linestyle='dotted', color=color)
ax2.plot(block_sizes, miss_rate_150_cache_1, marker='x', label='Cache Miss Rate (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 100))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(block_sizes, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(block_sizes, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)

plt.title('Performance Metrics vs Block Size')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
cache_levels = [1, 2, 3]
total_cycles_128 = [76937677, 20140349, 12129641]
total_cycles_150 = [65085352, 26534944, 15008504]

# Data for Cache Misses for cache_1
misses_128_cache_1 = [64051, 56358, 64060]
misses_150_cache_1 = [55366, 55367, 64658]

# Data for AMAT for cache_1
amats_128_cache_1 = [267.128, 63.714, 40.239]
amats_150_cache_1 = [212.037, 80.181, 43.865]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Number of Cache Levels', fontsize=20)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(cache_levels, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(cache_levels, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)
ax1.set_xticks(cache_levels)
ax1.tick_params(axis='x', labelsize=12)

# Plot Cache Misses for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses', color=color, fontsize=20)
ax2.plot(cache_levels, misses_128_cache_1, marker='x', label='Cache Misses (128)', linestyle='dotted', color=color)
ax2.plot(cache_levels, misses_150_cache_1, marker='x', label='Cache Misses (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 90))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(cache_levels, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(cache_levels, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Performance Metrics vs Number of Cache Levels', fontsize=16)
plt.show()

# %% [markdown]
# # Gather Operation

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
associativity_levels = [2, 4, 8]
total_cycles_128 = [5323824, 5406792, 5343248]
total_cycles_150 = [5549971, 5588359, 5667199]

# Data for Cache Misses for cache_1
misses_128_cache_1 = [45946, 44853, 45261]
misses_150_cache_1 = [43370, 46592, 50677]

# Data for AMAT for cache_1
amats_128_cache_1 = [28.063, 28.012, 27.442]
amats_150_cache_1 = [27.247, 28.228, 28.690]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Cache Associativity Levels', fontsize=20)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(associativity_levels, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(associativity_levels, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=20)
ax1.tick_params(axis='x', labelsize=12)

# Plot Cache Misses for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses', color=color, fontsize=20)
ax2.plot(associativity_levels, misses_128_cache_1, marker='x', label='Cache Misses (128)', linestyle='dotted', color=color)
ax2.plot(associativity_levels, misses_150_cache_1, marker='x', label='Cache Misses (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 90))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(associativity_levels, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(associativity_levels, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Performance Metrics vs Cache Associativity Levels', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
block_sizes = [16, 32, 64]
total_cycles_128 = [5496376, 5000588, 4479360]
total_cycles_150 = [5629227, 5223015, 4755659]

# Data for Cache Misses for cache_1
misses_128_cache_1 = [47845, 24297, 11617]
misses_150_cache_1 = [47430, 23575, 12565]

# Data for AMAT for cache_1
amats_128_cache_1 = [28.467, 24.514, 23.419]
amats_150_cache_1 = [27.314, 24.823, 24.589]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Cache Block Sizes', fontsize=14)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(block_sizes, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(block_sizes, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)
ax1.tick_params(axis='x', labelsize=12)
# Plot Cache Misses for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses', color=color, fontsize=20)
ax2.plot(block_sizes, misses_128_cache_1, marker='x', label='Cache Misses (128)', linestyle='dotted', color=color)
ax2.plot(block_sizes, misses_150_cache_1, marker='x', label='Cache Misses (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 90))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(block_sizes, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(block_sizes, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Performance Metrics vs Cache Block Sizes', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
block_sizes = [1, 2, 3]
total_cycles_128 = [55843040, 9511312, 5187932]
total_cycles_150 = [58187296, 8932944, 5323824]

# Data for Cache Misses for cache_1
misses_128_cache_1 = [44879, 44890, 41929]
misses_150_cache_1 = [50166, 50276, 45946]

# Number of instructions
number_of_instructions_20 = 186697
number_of_instructions_32 = 496741

# Convert cache misses to miss rates
miss_rate_128_cache_1 = [miss / number_of_instructions_20 for miss in misses_128_cache_1]
miss_rate_150_cache_1 = [miss / number_of_instructions_32 for miss in misses_150_cache_1]

# Data for AMAT for cache_1
amats_128_cache_1 = [244.85, 45.41, 26.33]
amats_150_cache_1 = [267.42, 108.40, 28.06]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Number of Caches', fontsize=14)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(block_sizes, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(block_sizes, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)
ax1.tick_params(axis='x', labelsize=12)

# Plot Cache Miss Rates for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Miss Rate', color=color, fontsize=20)
ax2.plot(block_sizes, miss_rate_128_cache_1, marker='x', label='Cache Miss Rate (128)', linestyle='dotted', color=color)
ax2.plot(block_sizes, miss_rate_150_cache_1, marker='x', label='Cache Miss Rate (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 80))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(block_sizes, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(block_sizes, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Performance Metrics vs Number of Caches', fontsize=16)
plt.show()

# %% [markdown]
# # Convolution

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
block_sizes = [1, 2, 3]  # Number of caches
total_cycles_20 = [13239697, 2553545, 1629177]
total_cycles_32 = [53426741, 5419621, 3466785]

# Data for Cache Misses for cache_1
misses_20_cache_1 = [12088, 12088, 19574]
misses_32_cache_1 = [45459, 45459, 50264]

# Data for AMAT for cache_1
amats_20_cache_1 = [65.75, 10.73, 7.55]
amats_32_cache_1 = [92.51, 9.19, 5.55]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Number of Caches', fontsize=20)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(block_sizes, total_cycles_20, marker='o', label='Total Cycles (20)', color=color)
ax1.plot(block_sizes, total_cycles_32, marker='o', linestyle='--', label='Total Cycles (32)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)
ax1.tick_params(axis='x', labelsize=12)


# Plot Cache Misses for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses', color=color, fontsize=20)
ax2.plot(block_sizes, misses_20_cache_1, marker='x', label='Cache Misses (20)', linestyle='dotted', color=color)
ax2.plot(block_sizes, misses_32_cache_1, marker='x', label='Cache Misses (32)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 90))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(block_sizes, amats_20_cache_1, marker='s', label='AMAT (20)', linestyle='solid', color=color)
ax3.plot(block_sizes, amats_32_cache_1, marker='s', linestyle='dashed', label='AMAT (32)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Convolution Operation Performance Metrics vs Number of Caches', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
associativity_levels = [2, 4, 8]
total_cycles_128 = [5323824, 5406792, 5343248]
total_cycles_150 = [5549971, 5588359, 5667199]

# Data for Cache Misses for cache_1
misses_128_cache_1 = [45946, 44853, 45261]
misses_150_cache_1 = [43370, 46592, 50677]

# Data for AMAT for cache_1
amats_128_cache_1 = [28.063, 28.012, 27.442]
amats_150_cache_1 = [27.247, 28.228, 28.690]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Cache Associativity Levels', fontsize=20)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=14)
ax1.plot(associativity_levels, total_cycles_128, marker='o', label='Total Cycles (128)', color=color)
ax1.plot(associativity_levels, total_cycles_150, marker='o', linestyle='--', label='Total Cycles (150)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)
ax1.tick_params(axis='x', labelsize=12)

# Plot Cache Misses for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misse', color=color, fontsize=20)
ax2.plot(associativity_levels, misses_128_cache_1, marker='x', label='Cache Misses (128)', linestyle='dotted', color=color)
ax2.plot(associativity_levels, misses_150_cache_1, marker='x', label='Cache Misses (150)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 90))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(associativity_levels, amats_128_cache_1, marker='s', label='AMAT (128)', linestyle='solid', color=color)
ax3.plot(associativity_levels, amats_150_cache_1, marker='s', linestyle='dashed', label='AMAT (150)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Performance Metrics vs Cache Associativity Levels', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Total Cycles Taken
block_sizes = [16, 32, 64]
total_cycles_20 = [1629177, 1430181, 1249197]
total_cycles_32 = [3632997, 2790121, 2504085]

# Data for Cache Misses for cache_1
misses_20_cache_1 = [19574, 8950, 3202]
misses_32_cache_1 = [57423, 15941, 4824]

# Data for AMAT for cache_1
amats_20_cache_1 = [7.55, 6.33, 5.94]
amats_32_cache_1 = [5.98, 4.51, 4.30]

fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Total Cycles Taken
color = 'tab:blue'
ax1.set_xlabel('Block Sizes', fontsize=14)
ax1.set_ylabel('Total Cycles Taken', color=color, fontsize=20)
ax1.plot(block_sizes, total_cycles_20, marker='o', label='Total Cycles (Matrix Size 20)', color=color)
ax1.plot(block_sizes, total_cycles_32, marker='o', linestyle='--', label='Total Cycles (Matrix Size 32)', color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=12)
ax1.tick_params(axis='x', labelsize=12)

# Plot Cache Misses for cache_1
ax2 = ax1.twinx()
color = 'tab:green'
ax2.set_ylabel('Cache Misses', color=color, fontsize=20)
ax2.plot(block_sizes, misses_20_cache_1, marker='x', label='Cache Misses (Matrix Size 20)', linestyle='dotted', color=color)
ax2.plot(block_sizes, misses_32_cache_1, marker='x', label='Cache Misses (Matrix Size 32)', linestyle='dashdot', color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=12)

# Plot AMAT for cache_1
ax3 = ax1.twinx()
color = 'tab:red'
ax3.spines['right'].set_position(('outward', 90))
ax3.set_ylabel('AMAT', color=color, fontsize=20)
ax3.plot(block_sizes, amats_20_cache_1, marker='s', label='AMAT (Matrix Size 20)', linestyle='solid', color=color)
ax3.plot(block_sizes, amats_32_cache_1, marker='s', linestyle='dashed', label='AMAT (Matrix Size 32)', color=color)
ax3.tick_params(axis='y', labelcolor=color, labelsize=12)

fig.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)

plt.title('Convolution Operation Performance Metrics vs Block Sizes', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the caches from the extracted text
caches_data = {
    'cache_1': [
        {'accesses': 240677, 'hits': 176617},
        {'accesses': 240677, 'hits': 208047},
        {'accesses': 240677, 'hits': 221324},
        {'accesses': 262352, 'hits': 199271},
        {'accesses': 262352, 'hits': 223707},
        {'accesses': 262352, 'hits': 238301}
    ],
    'cache_2': [
        {'accesses': 55522, 'hits': 41382},
        {'accesses': 27354, 'hits': 13529},
        {'accesses': 16171, 'hits': 5858},
        {'accesses': 55964, 'hits': 38005},
        {'accesses': 34008, 'hits': 16734},
        {'accesses': 20328, 'hits': 7049}
    ],
    'cache_3': [
        {'accesses': 12871, 'hits': 7516},
        {'accesses': 12506, 'hits': 7060},
        {'accesses': 9074, 'hits': 3649},
        {'accesses': 16217, 'hits': 9162},
        {'accesses': 15459, 'hits': 8467},
        {'accesses': 11623, 'hits': 4789}
    ]
}

block_sizes = [16, 32, 64, 16, 32, 64]

# Calculate hit percentages for each cache
hit_percentages = {
    'cache_1': [(data['hits'] / data['accesses']) * 100 for data in caches_data['cache_1']],
    'cache_2': [(data['hits'] / data['accesses']) * 100 for data in caches_data['cache_2']],
    'cache_3': [(data['hits'] / data['accesses']) * 100 for data in caches_data['cache_3']]
}

# Plotting the hit percentages for each cache
plt.figure(figsize=(12, 6))

plt.plot(block_sizes, hit_percentages['cache_1'], marker='o', label='Cache 1')
plt.plot(block_sizes, hit_percentages['cache_2'], marker='s', label='Cache 2')
plt.plot(block_sizes, hit_percentages['cache_3'], marker='^', label='Cache 3')

plt.xlabel('Block Size')
plt.ylabel('Hit Percentage')
plt.title('Cache Hit Percentage vs. Block Size')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the caches from the extracted text
gather_operation_data = {
    'cache_1': [
        {'accesses': 184040, 'hits': 136195},
        {'accesses': 184040, 'hits': 159743},
        {'accesses': 184040, 'hits': 172423},
        {'accesses': 188395, 'hits': 140965},
        {'accesses': 188395, 'hits': 164820},
        {'accesses': 188395, 'hits': 175830}
    ],
    'cache_2': [
        {'accesses': 38811, 'hits': 32660},
        {'accesses': 21631, 'hits': 15841},
        {'accesses': 9720, 'hits': 5489},
        {'accesses': 41033, 'hits': 34845},
        {'accesses': 21311, 'hits': 15207},
        {'accesses': 10364, 'hits': 5499}
    ],
    'cache_3': [
        {'accesses': 5948, 'hits': 3178},
        {'accesses': 5500, 'hits': 2719},
        {'accesses': 4027, 'hits': 1292},
        {'accesses': 5953, 'hits': 3054},
        {'accesses': 5794, 'hits': 2846},
        {'accesses': 4632, 'hits': 1763}
    ]
}

block_sizes = [16, 32, 64, 16, 32, 64]

# Calculate hit percentages for each cache
hit_percentages = {
    'cache_1': [(data['hits'] / data['accesses']) * 100 for data in gather_operation_data['cache_1']],
    'cache_2': [(data['hits'] / data['accesses']) * 100 for data in gather_operation_data['cache_2']],
    'cache_3': [(data['hits'] / data['accesses']) * 100 for data in gather_operation_data['cache_3']]
}

# Plotting the hit percentages for each cache
plt.figure(figsize=(12, 6))

plt.plot(block_sizes, hit_percentages['cache_1'], marker='o', label='Cache 1')
plt.plot(block_sizes, hit_percentages['cache_2'], marker='s', label='Cache 2')
plt.plot(block_sizes, hit_percentages['cache_3'], marker='^', label='Cache 3')

plt.xlabel('Block Size')
plt.ylabel('Hit Percentage')
plt.title('Cache Hit Percentage vs. Block Size (Gather Operation)')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the caches from the extracted text for the Convolution Operation
convolution_operation_data = {
    'cache_1': [
        {'accesses': 186697, 'hits': 167123},
        {'accesses': 186697, 'hits': 177747},
        {'accesses': 186697, 'hits': 183495},
        {'accesses': 186697, 'hits': 174231},
        {'accesses': 496741, 'hits': 480800},
        {'accesses': 496741, 'hits': 491917}
    ],
    'cache_2': [
        {'accesses': 16765, 'hits': 15063},
        {'accesses': 8298, 'hits': 6607},
        {'accesses': 2745, 'hits': 1643},
        {'accesses': 11460, 'hits': 9843},
        {'accesses': 14507, 'hits': 11824},
        {'accesses': 4181, 'hits': 2046}
    ],
    'cache_3': [
        {'accesses': 1571, 'hits': 1009},
        {'accesses': 1556, 'hits': 985},
        {'accesses': 1015, 'hits': 428},
        {'accesses': 1493, 'hits': 933},
        {'accesses': 2500, 'hits': 1487},
        {'accesses': 1978, 'hits': 923}
    ]
}

block_sizes = [16, 32, 64, 16, 32, 64]

# Calculate hit percentages for each cache
hit_percentages = {
    'cache_1': [(data['hits'] / data['accesses']) * 100 for data in convolution_operation_data['cache_1']],
    'cache_2': [(data['hits'] / data['accesses']) * 100 for data in convolution_operation_data['cache_2']],
    'cache_3': [(data['hits'] / data['accesses']) * 100 for data in convolution_operation_data['cache_3']]
}

# Plotting the hit percentages for each cache
plt.figure(figsize=(12, 6))

plt.plot(block_sizes, hit_percentages['cache_1'], marker='o', label='Cache 1')
plt.plot(block_sizes, hit_percentages['cache_2'], marker='s', label='Cache 2')
plt.plot(block_sizes, hit_percentages['cache_3'], marker='^', label='Cache 3')

plt.xlabel('Block Size')
plt.ylabel('Hit Percentage')
plt.title('Cache Hit Percentage vs. Block Size (Convolution Operation)')
plt.legend()
plt.grid(True)

plt.show()
